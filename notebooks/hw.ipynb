# %%
print("hello world")
# Out:
# hello world

# %%
#%pip install requests

# %%
import requests

# %%
health_path = "/healthz"
base_url = "http://localhost:8002"
endpoint = f"{base_url}{health_path}"
endpoint
# Out:
# 'http://localhost:8002/healthz'

# %%
response = requests.get(endpoint)
print(response.ok)
# Out:
# True

# %%
path = "/api/events/"
base_url = "http://localhost:8002"
create_endpoint = f"{base_url}{path}"

response = requests.post(create_endpoint, json={"page": "/test+", "description": '123'}) # HTTP POST
print(response.headers)
print('ok', response.ok)
if response.ok:
    data = response.json()
    print(data, type(data), data.get('items'))
else:
    print(response.text)
# Out:
# {'date': 'Sun, 09 Nov 2025 22:11:57 GMT', 'server': 'uvicorn', 'content-length': '44', 'content-type': 'application/json'}
# ok True
# {'page': '/test+', 'description': '123', 'id': 2} <class 'dict'> None
